# %%
import matplotlib
import pyrosm
from pyrosm import get_data

# %%
fp = pyrosm.get_data("Berlin")
osm = pyrosm.OSM(fp)
#maybe make a loop for 10 cities?#

# %%
print(fp)
# Out:
# /tmp/pyrosm/Berlin.osm.pbf

# %%
osm = pyrosm.OSM(fp, bounding_box=[13.294333, 52.454927, 13.50205, 52.574409])
#how would we get the bounding box for the cities automatically#
bi_berlin = osm.get_buildings()

# %%
print(osm)
# Out:
# <pyrosm.pyrosm.OSM object at 0x7f81a77434d0>

# %%
bi_berlin.plot()
# Out:
# <Axes: >
