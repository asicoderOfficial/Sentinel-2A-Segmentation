# %%
import matplotlib as plt
import pyrosm
from pyrosm import get_data
from matplotlib.pyplot import plot, savefig

# %%
fp = pyrosm.get_data("Berlin")
osm = pyrosm.OSM(fp)

# %%
print(fp)
# Out:
# /tmp/pyrosm/Berlin.osm.pbf

# %%
osm = pyrosm.OSM(fp, bounding_box=[13.294333, 52.454927, 13.50205, 52.574409])

# %%
bi_berlin = osm.get_buildings()

# %%
print(osm)

# %%
ax = bi_berlin.plot(figsize=(14.26, 12.98))
ax.set_axis_off()
fig=ax.figure
fig.savefig('bi_berlin_demo', transparent=True)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
im = plt.imread('/home/starkklaus/Downloads/output_image_gray.png')
implot = plt.imshow(im)

# %%
from PIL import Image

# %%
# Front Image 
filename = '/home/starkklaus/bi_berlin_demo.png'
  
# Back Image 
filename1 = '/home/starkklaus/Downloads/output_image_gray.png'
  
# Open Front Image 
frontImage = Image.open('/home/starkklaus/bi_berlin_demo.png') 
  
# Open Background Image 
background = Image.open('/home/starkklaus/Downloads/output_image_gray.png') 
  
# Convert image to RGBA 
frontImage = frontImage.convert("RGBA") 
  
# Convert image to RGBA 
background = background.convert("RGBA") 
  
# Paste the frontImage at (width, height) 
background.paste(frontImage, frontImage) 
  
# Save this image 
background.save("new.png", format="png")

#struggling to put the images together the correct way :/
